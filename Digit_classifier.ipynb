# %%
from fastai.vision.all import*
path = untar_data(URLs.MNIST_SAMPLE)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3219456' class='' max='3214948' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.14% [3219456/3214948 00:00&lt;00:00]
#     </div>

# %%
path.ls()
# Out:
# (#3) [Path('C:/Users/Joyal/.fastai/data/mnist_sample/labels.csv'),Path('C:/Users/Joyal/.fastai/data/mnist_sample/train'),Path('C:/Users/Joyal/.fastai/data/mnist_sample/valid')]

# %%
(path/'train').ls()
# Out:
# (#2) [Path('C:/Users/Joyal/.fastai/data/mnist_sample/train/3'),Path('C:/Users/Joyal/.fastai/data/mnist_sample/train/7')]

# %%
threes = (path/'train'/'3').ls().sorted()
sevens = (path/'train'/'7').ls().sorted()

# %%
im3_path = threes[1]
im3 = Image.open(im3_path)
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>

# %%
im3_t = tensor(im3)
df = pd.DataFrame(im3_t[4:15,4:22])
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# #T_c775e_row0_col0, #T_c775e_row0_col1, #T_c775e_row0_col2, #T_c775e_row0_col3, #T_c775e_row0_col4, #T_c775e_row0_col5, #T_c775e_row0_col6, #T_c775e_row0_col7, #T_c775e_row0_col8, #T_c775e_row0_col9, #T_c775e_row0_col10, #T_c775e_row0_col11, #T_c775e_row0_col12, #T_c775e_row0_col13, #T_c775e_row0_col14, #T_c775e_row0_col15, #T_c775e_row0_col16, #T_c775e_row0_col17, #T_c775e_row1_col0, #T_c775e_row1_col1, #T_c775e_row1_col2, #T_c775e_row1_col3, #T_c775e_row1_col4, #T_c775e_row1_col15, #T_c775e_row1_col16, #T_c775e_row1_col17, #T_c775e_row2_col0, #T_c775e_row2_col1, #T_c775e_row2_col2, #T_c775e_row2_col15, #T_c775e_row2_col16, #T_c775e_row2_col17, #T_c775e_row3_col0, #T_c775e_row3_col15, #T_c775e_row3_col16, #T_c775e_row3_col17, #T_c775e_row4_col0, #T_c775e_row4_col6, #T_c775e_row4_col7, #T_c775e_row4_col8, #T_c775e_row4_col9, #T_c775e_row4_col10, #T_c775e_row4_col15, #T_c775e_row4_col16, #T_c775e_row4_col17, #T_c775e_row5_col0, #T_c775e_row5_col5, #T_c775e_row5_col6, #T_c775e_row5_col7, #T_c775e_row5_col8, #T_c775e_row5_col9, #T_c775e_row5_col15, #T_c775e_row5_col16, #T_c775e_row5_col17, #T_c775e_row6_col0, #T_c775e_row6_col1, #T_c775e_row6_col2, #T_c775e_row6_col3, #T_c775e_row6_col4, #T_c775e_row6_col5, #T_c775e_row6_col6, #T_c775e_row6_col7, #T_c775e_row6_col8, #T_c775e_row6_col9, #T_c775e_row6_col14, #T_c775e_row6_col15, #T_c775e_row6_col16, #T_c775e_row6_col17, #T_c775e_row7_col0, #T_c775e_row7_col1, #T_c775e_row7_col2, #T_c775e_row7_col3, #T_c775e_row7_col4, #T_c775e_row7_col5, #T_c775e_row7_col6, #T_c775e_row7_col13, #T_c775e_row7_col14, #T_c775e_row7_col15, #T_c775e_row7_col16, #T_c775e_row7_col17, #T_c775e_row8_col0, #T_c775e_row8_col1, #T_c775e_row8_col2, #T_c775e_row8_col3, #T_c775e_row8_col4, #T_c775e_row8_col13, #T_c775e_row8_col14, #T_c775e_row8_col15, #T_c775e_row8_col16, #T_c775e_row8_col17, #T_c775e_row9_col0, #T_c775e_row9_col1, #T_c775e_row9_col2, #T_c775e_row9_col3, #T_c775e_row9_col4, #T_c775e_row9_col16, #T_c775e_row9_col17, #T_c775e_row10_col0, #T_c775e_row10_col1, #T_c775e_row10_col2, #T_c775e_row10_col3, #T_c775e_row10_col4, #T_c775e_row10_col5, #T_c775e_row10_col6, #T_c775e_row10_col17 {
#   font-size: 6pt;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_c775e_row1_col5 {
#   font-size: 6pt;
#   background-color: #efefef;
#   color: #000000;
# }
# #T_c775e_row1_col6, #T_c775e_row1_col13 {
#   font-size: 6pt;
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_c775e_row1_col7 {
#   font-size: 6pt;
#   background-color: #4a4a4a;
#   color: #f1f1f1;
# }
# #T_c775e_row1_col8, #T_c775e_row1_col9, #T_c775e_row1_col10, #T_c775e_row2_col5, #T_c775e_row2_col6, #T_c775e_row2_col7, #T_c775e_row2_col11, #T_c775e_row2_col12, #T_c775e_row2_col13, #T_c775e_row3_col4, #T_c775e_row3_col12, #T_c775e_row3_col13, #T_c775e_row4_col1, #T_c775e_row4_col2, #T_c775e_row4_col3, #T_c775e_row4_col12, #T_c775e_row4_col13, #T_c775e_row5_col12, #T_c775e_row6_col11, #T_c775e_row9_col11, #T_c775e_row10_col11, #T_c775e_row10_col12, #T_c775e_row10_col13, #T_c775e_row10_col14, #T_c775e_row10_col15, #T_c775e_row10_col16 {
#   font-size: 6pt;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c775e_row1_col11 {
#   font-size: 6pt;
#   background-color: #606060;
#   color: #f1f1f1;
# }
# #T_c775e_row1_col12 {
#   font-size: 6pt;
#   background-color: #4d4d4d;
#   color: #f1f1f1;
# }
# #T_c775e_row1_col14 {
#   font-size: 6pt;
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_c775e_row2_col3 {
#   font-size: 6pt;
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_c775e_row2_col4, #T_c775e_row8_col6 {
#   font-size: 6pt;
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_c775e_row2_col8, #T_c775e_row2_col14, #T_c775e_row3_col14 {
#   font-size: 6pt;
#   background-color: #171717;
#   color: #f1f1f1;
# }
# #T_c775e_row2_col9, #T_c775e_row3_col11 {
#   font-size: 6pt;
#   background-color: #4b4b4b;
#   color: #f1f1f1;
# }
# #T_c775e_row2_col10, #T_c775e_row7_col10, #T_c775e_row8_col8, #T_c775e_row8_col10, #T_c775e_row9_col8, #T_c775e_row9_col10 {
#   font-size: 6pt;
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_c775e_row3_col1 {
#   font-size: 6pt;
#   background-color: #272727;
#   color: #f1f1f1;
# }
# #T_c775e_row3_col2 {
#   font-size: 6pt;
#   background-color: #0a0a0a;
#   color: #f1f1f1;
# }
# #T_c775e_row3_col3 {
#   font-size: 6pt;
#   background-color: #050505;
#   color: #f1f1f1;
# }
# #T_c775e_row3_col5 {
#   font-size: 6pt;
#   background-color: #333333;
#   color: #f1f1f1;
# }
# #T_c775e_row3_col6 {
#   font-size: 6pt;
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_c775e_row3_col7, #T_c775e_row3_col10 {
#   font-size: 6pt;
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_c775e_row3_col8 {
#   font-size: 6pt;
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_c775e_row3_col9 {
#   font-size: 6pt;
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_c775e_row4_col4 {
#   font-size: 6pt;
#   background-color: #1b1b1b;
#   color: #f1f1f1;
# }
# #T_c775e_row4_col5 {
#   font-size: 6pt;
#   background-color: #e0e0e0;
#   color: #000000;
# }
# #T_c775e_row4_col11 {
#   font-size: 6pt;
#   background-color: #4e4e4e;
#   color: #f1f1f1;
# }
# #T_c775e_row4_col14 {
#   font-size: 6pt;
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_c775e_row5_col1 {
#   font-size: 6pt;
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_c775e_row5_col2, #T_c775e_row5_col3 {
#   font-size: 6pt;
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_c775e_row5_col4, #T_c775e_row7_col7 {
#   font-size: 6pt;
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_c775e_row5_col10, #T_c775e_row10_col7 {
#   font-size: 6pt;
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_c775e_row5_col11 {
#   font-size: 6pt;
#   background-color: #222222;
#   color: #f1f1f1;
# }
# #T_c775e_row5_col13, #T_c775e_row6_col12 {
#   font-size: 6pt;
#   background-color: #090909;
#   color: #f1f1f1;
# }
# #T_c775e_row5_col14 {
#   font-size: 6pt;
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_c775e_row6_col10, #T_c775e_row7_col11, #T_c775e_row9_col6 {
#   font-size: 6pt;
#   background-color: #060606;
#   color: #f1f1f1;
# }
# #T_c775e_row6_col13 {
#   font-size: 6pt;
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_c775e_row7_col8 {
#   font-size: 6pt;
#   background-color: #b6b6b6;
#   color: #000000;
# }
# #T_c775e_row7_col9 {
#   font-size: 6pt;
#   background-color: #252525;
#   color: #f1f1f1;
# }
# #T_c775e_row7_col12 {
#   font-size: 6pt;
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_c775e_row8_col5 {
#   font-size: 6pt;
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_c775e_row8_col7 {
#   font-size: 6pt;
#   background-color: #101010;
#   color: #f1f1f1;
# }
# #T_c775e_row8_col9, #T_c775e_row9_col9 {
#   font-size: 6pt;
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_c775e_row8_col11 {
#   font-size: 6pt;
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_c775e_row8_col12 {
#   font-size: 6pt;
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_c775e_row9_col5 {
#   font-size: 6pt;
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_c775e_row9_col7 {
#   font-size: 6pt;
#   background-color: #030303;
#   color: #f1f1f1;
# }
# #T_c775e_row9_col12 {
#   font-size: 6pt;
#   background-color: #181818;
#   color: #f1f1f1;
# }
# #T_c775e_row9_col13 {
#   font-size: 6pt;
#   background-color: #303030;
#   color: #f1f1f1;
# }
# #T_c775e_row9_col14 {
#   font-size: 6pt;
#   background-color: #a9a9a9;
#   color: #f1f1f1;
# }
# #T_c775e_row9_col15 {
#   font-size: 6pt;
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_c775e_row10_col8, #T_c775e_row10_col9 {
#   font-size: 6pt;
#   background-color: #bababa;
#   color: #000000;
# }
# #T_c775e_row10_col10 {
#   font-size: 6pt;
#   background-color: #393939;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c775e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c775e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c775e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c775e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c775e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c775e_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_c775e_level0_col5" class="

# %%
seven_tensors = [tensor(Image.open(o)) for o in sevens]
three_tensors = [tensor(Image.open(o)) for o in threes]
len(three_tensors),len(seven_tensors)
# Out:
# (6131, 6265)

# %%
show_image(three_tensors[1]);

# %%
stacked_sevens = torch.stack(seven_tensors).float()/255
stacked_threes = torch.stack(three_tensors).float()/255
stacked_threes.shape
# Out:
# torch.Size([6131, 28, 28])
